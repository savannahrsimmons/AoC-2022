# %%
input = open('day_9.txt')

visited = set()

h = (0,0)
t = (0,0)
visited.add((0,0))

for line in input.readlines():
    line = line.strip()
    dir, steps = line[0], int(line[2:])
    #print("dir " + dir)
    #print("steps " + str(steps))
    if dir == 'L':
        for i in range(0,steps):
            h = (h[0] - 1, h[1])
            if t[0] - h[0] == 2:
                t = (t[0] - 1, h[1])
            visited.add(t)
    elif dir == 'R':
        for i in range(0,steps):
            h = (h[0] + 1, h[1])
            if h[0] - t[0] == 2:
                t = (t[0] + 1, h[1])
            visited.add(t)
    elif dir == 'U':
        for i in range(0,steps):
            h = (h[0], h[1] + 1)
            if h[1] - t[1] == 2:
                t = (h[0], t[1] + 1)
            visited.add(t)
    else:
        for i in range(0,steps):
            h = (h[0], h[1] - 1)
            if t[1] - h[1] == 2:
                t = (h[0], t[1] - 1) 
            visited.add(t)
                

print(visited)
print(len(visited))
# Out:
# {(-47, -192), (-61, -127), (-53, -7), (-123, -66), (-65, -125), (-140, -299), (-89, -68), (-50, -140), (-86, -63), (-26, -12), (-64, -304), (-49, 4), (-115, -350), (-112, -345), (-66, -229), (-94, -62), (-94, -291), (-103, -111), (-128, -168), (-117, -73), (-19, 4), (-94, -170), (-122, -3), (-55, -242), (-128, -47), (-87, -46), (-43, -3), (-58, -126), (-66, -216), (-50, -6), (-62, -124), (3, 5), (-63, -349), (-39, 8), (-58, -234), (-69, -164), (-157, -277), (-4, 2), (-125, -59), (-139, -223), (-62, -3), (-90, -331), (-44, -215), (-60, -223), (-50, 7), (-69, -272), (-97, -105), (-97, -334), (-130, -282), (-150, -224), (-104, -108), (-63, -336), (-69, -151), (-83, -49), (-102, -328), (-56, -212), (-53, -207), (-100, -282), (-155, -218), (-81, -269), (-109, -331), (-63, -215), (-74, -145), (-47, -271), (-75, -333), (-70, -255), (-120, -76), (-72, -328), (-95, -312), (-68, -209), (-118, -30), (-137, -309), (-151, -207), (-77, -258), (-56, -199), (-70, -134), (-72, -207), (-53, -194), (-81, -27), (-155, -205), (-123, -253), (-65, -312), (-107, -309), (-28, -16), (-163, -204), (-89, -255), (-72, -315), (-105, -263), (-114, -83), (-133, -325), (-114, -312), (-35, -19), (-49, -183), (-52, -252), (-102, -73), (-154, -263), (-75, -199), (-122, -311), (-177, -247), (-72, -194), (-40, -13), (-107, -67), (-107, -296), (-28, -3), (-140, -244), (-59, -134), (-71, -252), (-119, -64), (-87, -112), (-126, -67), (-107, -54), (-25, -15), (-6, -2), (-22, -10), (-3, 3), (-110, -352), (-124, -287), (-59, -121), (-134, -295), (-131, -290), (-66, -161), (-99, -338), (-64, -115), (-18, 1), (1, 14), (-15, 6), (-120, -276), (-117, -5), (-129, -59), (-85, -53), (-25, -1), (-25, -2), (-6, 11), (-3, 16), (-141, -214), (-124, -45), (-124, -274), (-138, -172), (-111, -335), (-120, -155), (-134, -53), (-29, 0), (-62, -177), (-76, -112), (-131, -48), (-109, -289), (-90, -276), (-132, -273), (-146, -171), (-174, -270), (-69, -217), (-37, 1), (-56, -278), (-152, -215), (-67, -171), (-120, -263), (-81, -335), (-136, -271), (-123, -332), (-58, -166), (-146, -279), (-60, -276), (-41, -263), (-88, -109), (-102, -273), (-144, -270), (-134, -40), (-54, -340), (-30, 17), (-90, -263), (-96, -337), (-151, -273), (-46, -220), (-146, -158), (-60, -155), (-74, -319), (-84, -327), (-100, -335), (-81, -322), (-114, -270), (-137, -254), (0, 17), (-160, -201), (-74, -198), (-121, -273), (-163, -270), (-89, -321), (-105, -329), (-86, -316), (-90, -21), (-128, -313), (-96, -324), (-65, -257), (-93, -319), (-162, -190), (-47, -203), (-75, -36), (-116, -74), (-116, -303), (-72, -31), (-100, -93), (-54, -206), (-49, -128), (-101, -318), (-60, -21), (-121, -31), (-102, -18), (-135, -195), (-61, -246), (-163, -257), (-109, -21), (-49, -7), (-65, -244), (-33, -26), (-71, -318), (-75, -23), (-113, -315), (-100, -80), (-82, -63), (-156, -241), (-65, -123), (-117, -313), (-71, -197), (-140, -297), (-89, -66), (-50, -138), (-86, -61), (-138, -251), (-64, -302), (-71, -305), (-94, -60), (-94, -289), (-114, -1), (-150, -248), (-38, -7), (-76, -299), (-105, -61), (-83, -302), (-138, -238), (-128, -45), (-148, -283), (-50, -4), (-31, 9), (-64, -168), (-152, -281), (-62, -122), (3, 7), (-39, 10), (-69, -162), (-4, 4), (-125, -286), (-139, -221), (-1, 13), (-90, -329), (-178, -213), (-60, -221), (-97, -103), (-130, -280), (-72, -339), (-48, -211), (-169, -272), (-49, -207), (-77, -269), (-179, -280), (-56, -210), (-125, -44), (-72, -218), (-53, -205), (-100, -280), (-109, -329), (-142, -277), (-123, -264), (-63, -213), (-74, -143), (-130, -38), (-111, -25), (-70, -253), (-72, -326), (-100, -159), (-95, -310), (-68, -207), (-49, -194), (-118, -28), (-137, -307), (-121, -326), (-61, -312), (-56, -197), (-70, -132), (-177, -258), (-72, -205), (-123, -251), (-129, -325), (-65, -310), (-126, -320), (-107, -307), (-47, -256), (-89, -253), (-40, -132), (-95, -68), (-114, -310), (-35, -17), (-147, -258), (-68, -194), (-170, -242), (-52, -250), (-70, -119), (-177, -245), (-40, -11), (-59, -253), (-101, -2 ...
# 6357

# %%
# proud of my code for officially becoming ungovernable

input = open('day_9.txt')

visited = set()

rope = [(0,0)] * 10

visited.add((0,0))

        
def move_rope(a_rope):
    for i in range(1,10):
        if rope[i][0] - rope[i-1][0] == 2:
            if rope[i][1] - rope[i-1][1] == 2:
                rope[i] = (rope[i][0] - 1, rope[i][1] - 1)
            elif rope[i-1][1] - rope[i][1] == 2:
                rope[i] = (rope[i][0] - 1, rope[i][1] + 1)
            else:
                rope[i] = (rope[i][0] - 1, rope[i-1][1])
        elif rope[i-1][0] - rope[i][0] == 2:
            if rope[i][1] - rope[i-1][1] == 2:
                rope[i] = (rope[i][0] + 1, rope[i][1] - 1)
            elif rope[i-1][1] - rope[i][1] == 2:
                rope[i] = (rope[i][0] + 1, rope[i][1] + 1)
            else:
                rope[i] = (rope[i][0] + 1, rope[i-1][1])
        elif rope[i][1] - rope[i-1][1] == 2:
            rope[i] = (rope[i-1][0], rope[i][1] - 1)
        elif rope[i-1][1] - rope[i][1] == 2:
            rope[i] = (rope[i-1][0], rope[i][1] + 1)
            

    

for line in input.readlines():
    line = line.strip()
    dir, steps = line[0], int(line[2:])
    #print("dir " + dir)
    #print("steps " + str(steps))
    if dir == 'L':
        for i in range(0,steps):
            rope[0] = (rope[0][0] - 1, rope[0][1])
            for i in range(1,10):
                if rope[i][0] - rope[i-1][0] == 2:
                    if rope[i][1] - rope[i-1][1] == 2:
                        rope[i] = (rope[i][0] - 1, rope[i][1] - 1)
                    elif rope[i-1][1] - rope[i][1] == 2:
                        rope[i] = (rope[i][0] - 1, rope[i][1] + 1)
                    else:
                        rope[i] = (rope[i][0] - 1, rope[i-1][1])
                elif rope[i-1][0] - rope[i][0] == 2:
                    if rope[i][1] - rope[i-1][1] == 2:
                        rope[i] = (rope[i][0] + 1, rope[i][1] - 1)
                    elif rope[i-1][1] - rope[i][1] == 2:
                        rope[i] = (rope[i][0] + 1, rope[i][1] + 1)
                    else:
                        rope[i] = (rope[i][0] + 1, rope[i-1][1])
                elif rope[i][1] - rope[i-1][1] == 2:
                    rope[i] = (rope[i-1][0], rope[i][1] - 1)
                elif rope[i-1][1] - rope[i][1] == 2:
                    rope[i] = (rope[i-1][0], rope[i][1] + 1)
            visited.add(rope[-1])
            #print(rope)
            #print('---')
    elif dir == 'R':
        for i in range(0,steps):
            rope[0] = (rope[0][0] + 1, rope[0][1])
            for i in range(1,10):
                if rope[i][0] - rope[i-1][0] == 2:
                    if rope[i][1] - rope[i-1][1] == 2:
                        rope[i] = (rope[i][0] - 1, rope[i][1] - 1)
                    elif rope[i-1][1] - rope[i][1] == 2:
                        rope[i] = (rope[i][0] - 1, rope[i][1] + 1)
                    else:
                        rope[i] = (rope[i][0] - 1, rope[i-1][1])
                elif rope[i-1][0] - rope[i][0] == 2:
                    if rope[i][1] - rope[i-1][1] == 2:
                        rope[i] = (rope[i][0] + 1, rope[i][1] - 1)
                    elif rope[i-1][1] - rope[i][1] == 2:
                        rope[i] = (rope[i][0] + 1, rope[i][1] + 1)
                    else:
                        rope[i] = (rope[i][0] + 1, rope[i-1][1])
                elif rope[i][1] - rope[i-1][1] == 2:
                    rope[i] = (rope[i-1][0], rope[i][1] - 1)
                elif rope[i-1][1] - rope[i][1] == 2:
                    rope[i] = (rope[i-1][0], rope[i][1] + 1)
            visited.add(rope[-1])
            #print(rope)
            #print('---')
    elif dir == 'U':
        for i in range(0,steps):
            rope[0] = (rope[0][0], rope[0][1] + 1)
            for i in range(1,10):
                if rope[i][0] - rope[i-1][0] == 2:
                    if rope[i][1] - rope[i-1][1] == 2:
                        rope[i] = (rope[i][0] - 1, rope[i][1] - 1)
                    elif rope[i-1][1] - rope[i][1] == 2:
                        rope[i] = (rope[i][0] - 1, rope[i][1] + 1)
                    else:
                        rope[i] = (rope[i][0] - 1, rope[i-1][1])
                elif rope[i-1][0] - rope[i][0] == 2:
                    if rope[i][1] - rope[i-1][1] == 2:
                        rope[i] = (rope[i][0] + 1, rope[i][1] - 1)
                    elif rope[i-1][1] - rope[i][1] == 2:
                        rope[i] = (rope[i][0] + 1, rope[i][1] + 1)
                    else:
                        rope[i] = (rope[i][0] + 1, rope[i-1][1])
                elif rope[i][1] - rope[i-1][1] == 2:
                    rope[i] = (rope[i-1][0], rope[i][1] - 1)
                elif rope[i-1][1] - rope[i][1] == 2:
                    rope[i] = (rope[i-1][0], rope[i][1] + 1)
            visited.add(rope[-1])
            #print(rope)
            #print('---')
    else:
        for i in range(0,steps):
            rope[0] = (rope[0][0], rope[0][1] - 1)
            for i in range(1,10):
                if rope[i][0] - rope[i-1][0] == 2:
                    if rope[i][1] - rope[i-1][1] == 2:
                        rope[i] = (rope[i][0] - 1, rope[i][1] - 1)
                    elif rope[i-1][1] - rope[i][1] == 2:
                        rope[i] = (rope[i][0] - 1, rope[i][1] + 1)
                    else:
                        rope[i] = (rope[i][0] - 1, rope[i-1][1])
                elif rope[i-1][0] - rope[i][0] == 2:
                    if rope[i][1] - rope[i-1][1] == 2:
                        rope[i] = (rope[i][0] + 1, rope[i][1] - 1)
                    elif rope[i-1][1] - rope[i][1] == 2:
                        rope[i] = (rope[i][0] + 1, rope[i][1] + 1)
                    else:
                        rope[i] = (rope[i][0] + 1, rope[i-1][1])
                elif rope[i][1] - rope[i-1][1] == 2:
                    rope[i] = (rope[i-1][0], rope[i][1] - 1)
                elif rope[i-1][1] - rope[i][1] == 2:
                    rope[i] = (rope[i-1][0], rope[i][1] + 1)
            visited.add(rope[-1])
            #print(rope)
            #print('---')
            
print(len(visited))

#print(visited)
# Out:
# 2627

# %%
# tried to move move_rope out to a function but then got the wrong answer so lol w/e

input = open('day_9.txt')

visited = set()

rope = [(0,0)] * 10

visited.add((0,0))

        
def move_rope(a_rope):
    for i in range(1,10):
        if rope[i][0] - rope[i-1][0] == 2:
            if rope[i][1] - rope[i-1][1] == 2:
                rope[i] = (rope[i][0] - 1, rope[i][1] - 1)
            elif rope[i-1][1] - rope[i][1] == 2:
                rope[i] = (rope[i][0] - 1, rope[i][1] + 1)
            else:
                rope[i] = (rope[i][0] - 1, rope[i-1][1])
        elif rope[i-1][0] - rope[i][0] == 2:
            if rope[i][1] - rope[i-1][1] == 2:
                rope[i] = (rope[i][0] + 1, rope[i][1] - 1)
            elif rope[i-1][1] - rope[i][1] == 2:
                rope[i] = (rope[i][0] + 1, rope[i][1] + 1)
            else:
                rope[i] = (rope[i][0] + 1, rope[i-1][1])
        elif rope[i][1] - rope[i-1][1] == 2:
            rope[i] = (rope[i-1][0], rope[i][1] - 1)
        elif rope[i-1][1] - rope[i][1] == 2:
            rope[i] = (rope[i-1][0], rope[i][1] + 1)
            

    

for line in input.readlines():
    line = line.strip()
    dir, steps = line[0], int(line[2:])
    #print("dir " + dir)
    #print("steps " + str(steps))
    if dir == 'L':
        for i in range(0,steps):
            rope[0] = (rope[0][0] - 1, rope[0][1])
            move_rope(rope)
            #print(rope)
            #print('---')
    elif dir == 'R':
        for i in range(0,steps):
            rope[0] = (rope[0][0] + 1, rope[0][1])
            move_rope(rope)
            visited.add(rope[-1])
            #vis(rope)
            #print('---')
    elif dir == 'U':
        for i in range(0,steps):
            rope[0] = (rope[0][0], rope[0][1] + 1)
            move_rope(rope)
            visited.add(rope[-1])
            #vis(rope)
            #print('---')
    else:
        for i in range(0,steps):
            rope[0] = (rope[0][0], rope[0][1] - 1)
            move_rope(rope)
            visited.add(rope[-1])
            #vis(rope)
            #print('---')
            
print(len(visited))

#print(visited)
# Out:
# 2161
